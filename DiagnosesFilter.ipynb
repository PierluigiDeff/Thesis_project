# %%
import pandas as pd
data= pd.read_csv("D_ICD_DIAGNOSES.csv")
data
# Out:
#        ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0         174     01166     TB pneumonia-oth test
# 1         175     01170    TB pneumothorax-unspec
# 2         176     01171   TB pneumothorax-no exam
# 3         177     01172  TB pneumothorx-exam unkn
# 4         178     01173  TB pneumothorax-micro dx
# ...       ...       ...                       ...
# 14562   14432     V7399     Scrn unspcf viral dis
# 14563   14433      V740     Screening for cholera
# 14564   14434      V741    Screening-pulmonary TB
# 14565   14435      V742     Screening for leprosy
# 14566   14436      V743  Screening for diphtheria
#
#                                               LONG_TITLE
# 0      Tuberculous pneumonia [any form], tubercle bac...
# 1                  Tuberculous pneumothorax, unspecified
# 2      Tuberculous pneumothorax, bacteriological or h...
# 3      Tuberculous pneumothorax, bacteriological or h...
# 4      Tuberculous pneumothorax, tubercle bacilli fou...
# ...

# %%
data1= pd.read_csv("DIAGNOSES_ICD.csv")
data1
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 1         1298         109   172335      2.0       486
# 2         1299         109   172335      3.0     58281
# 3         1300         109   172335      4.0      5855
# 4         1301         109   172335      5.0      4254
# ...        ...         ...      ...      ...       ...
# 651042  639798       97503   188195      2.0     20280
# 651043  639799       97503   188195      3.0     V5869
# 651044  639800       97503   188195      4.0     V1279
# 651045  639801       97503   188195      5.0      5275
# 651046  639802       97503   188195      6.0      5569
#
# [651047 rows x 5 columns]

# %%
data2= pd.read_csv("PATIENTS.csv")
data2
# Out:
#        ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         234         249      F  2075-03-13 00:00:00                  NaN
# 1         235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         236         251      M  2090-03-15 00:00:00                  NaN
# 3         237         252      M  2078-03-06 00:00:00                  NaN
# 4         238         253      F  2089-11-26 00:00:00                  NaN
# ...       ...         ...    ...                  ...                  ...
# 46515   31840       44089      M  2026-05-25 00:00:00                  NaN
# 46516   31841       44115      F  2124-07-27 00:00:00                  NaN
# 46517   31842       44123      F  2049-11-26 00:00:00  2135-01-12 00:00:00
# 46518   31843       44126      F  2076-07-25 00:00:00                  NaN
# 46519   31844       44128      M  2098-07-25 00:00:00                  NaN
#
#                   DOD_HOSP DOD_SSN  EXPIRE_FLAG
# ...

# %%
# read the top n rows of csv file as a dataframe
reviews_df = pd.read_csv("DIAGNOSES_ICD.csv", nrows=100)
# print the shape of the dataframe
print("Dataframe shape:", reviews_df.shape)
# Out:
# Dataframe shape: (100, 5)

# %%
print(reviews_df)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0     1297         109   172335        1     40301
# 1     1298         109   172335        2       486
# 2     1299         109   172335        3     58281
# 3     1300         109   172335        4      5855
# 4     1301         109   172335        5      4254
# ..     ...         ...      ...      ...       ...
# 95    1555         118   147035        2      V053
# 96    1556         119   135738        1     88122
# 97    1557         119   135738        2      9032
# 98    1558         119   135738        3      9033
# 99    1559         119   135738        4      9551
#
# [100 rows x 5 columns]

# %%
filtered = data1[(data1['SEQ_NUM'] == 1)]
print(filtered)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0         1297         109   172335      1.0     40301
# 14        1311         109   173633      1.0     40301
# 28        1488         112   174105      1.0     53100
# 33        1493         113   109976      1.0      1915
# 36        1496         114   178393      1.0     41401
# ...        ...         ...      ...      ...       ...
# 650989  639745       97488   152542      1.0       566
# 651000  639756       97488   161999      1.0     43411
# 651024  639780       97492   189314      1.0     34680
# 651032  639788       97497   168949      1.0      0529
# 651041  639797       97503   188195      1.0      7842
#
# [58929 rows x 5 columns]

# %%
filtered["ICD9_CODE"] = pd.to_numeric(filtered["ICD9_CODE"], errors='coerce')
print(filtered)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0         1297         109   172335      1.0    40301.0
# 14        1311         109   173633      1.0    40301.0
# 28        1488         112   174105      1.0    53100.0
# 33        1493         113   109976      1.0     1915.0
# 36        1496         114   178393      1.0    41401.0
# ...        ...         ...      ...      ...        ...
# 650989  639745       97488   152542      1.0      566.0
# 651000  639756       97488   161999      1.0    43411.0
# 651024  639780       97492   189314      1.0    34680.0
# 651032  639788       97497   168949      1.0      529.0
# 651041  639797       97503   188195      1.0     7842.0
#
# [58929 rows x 5 columns]
# <ipython-input-4-08ea2f51ed19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#filtered = filtered[(filtered['ICD9_CODE'] > 3900.0 & filtered['ICD9_CODE'] < 4599.0 & 
                    # filtered['ICD9_CODE'] > 39000.0 & filtered['ICD9_CODE'] < 45999.0)]
filtered1 = filtered[(filtered['ICD9_CODE'] > 3900)]
print(filtered1)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0         1297         109   172335      1.0    40301.0
# 14        1311         109   173633      1.0    40301.0
# 28        1488         112   174105      1.0    53100.0
# 36        1496         114   178393      1.0    41401.0
# 63        1523         117   140784      1.0     5715.0
# ...        ...         ...      ...      ...        ...
# 650969  638477       97172   133092      1.0    53140.0
# 650983  639739       97484   172304      1.0    20280.0
# 651000  639756       97488   161999      1.0    43411.0
# 651024  639780       97492   189314      1.0    34680.0
# 651041  639797       97503   188195      1.0     7842.0
#
# [39915 rows x 5 columns]

# %%
filtered2 = filtered1[(filtered1['ICD9_CODE'] < 4599)]
print(filtered2)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 115       1575         124   112906      1.0     4412.0
# 238       1698         134   167887      1.0     3963.0
# 259       1719         136   184644      1.0     4375.0
# 378        607          75   112086      1.0     4241.0
# 452        681          85   116630      1.0     4241.0
# ...        ...         ...      ...      ...        ...
# 650725  632615       96010   192940      1.0     4241.0
# 650758  632648       96016   154486      1.0     4241.0
# 650764  632654       96017   123872      1.0     4241.0
# 650865  638373       97144   109999      1.0     4241.0
# 650895  638403       97149   125452      1.0     4271.0
#
# [5304 rows x 5 columns]

# %%
df = pd.DataFrame(filtered2)
print(df)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 115       1575         124   112906      1.0     4412.0
# 238       1698         134   167887      1.0     3963.0
# 259       1719         136   184644      1.0     4375.0
# 378        607          75   112086      1.0     4241.0
# 452        681          85   116630      1.0     4241.0
# ...        ...         ...      ...      ...        ...
# 650725  632615       96010   192940      1.0     4241.0
# 650758  632648       96016   154486      1.0     4241.0
# 650764  632654       96017   123872      1.0     4241.0
# 650865  638373       97144   109999      1.0     4241.0
# 650895  638403       97149   125452      1.0     4271.0
#
# [5304 rows x 5 columns]

# %%
df.to_csv('C:/Users/Utente principale/Desktop/Tesi Ms/filtered.csv')

# %%
filtered3=filtered[(filtered['ICD9_CODE'] > 39000)]
filtered4=filtered3[(filtered3['ICD9_CODE'] < 45999)]
print(filtered4)
# Out:
#         ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0         1297         109   172335      1.0    40301.0
# 14        1311         109   173633      1.0    40301.0
# 36        1496         114   178393      1.0    41401.0
# 110       1570         123   195632      1.0    41011.0
# 124       1584         124   134369      1.0    44021.0
# ...        ...         ...      ...      ...        ...
# 650341  637846       97023   148411      1.0    41401.0
# 650487  630661       95561   162189      1.0    42823.0
# 650664  631774       95818   102242      1.0    41401.0
# 650905  638413       97152   184093      1.0    42731.0
# 651000  639756       97488   161999      1.0    43411.0
#
# [11436 rows x 5 columns]

# %%
df1 = pd.DataFrame(filtered4)
df1.to_csv('C:/Users/Utente principale/Desktop/Tesi Ms/filtered1.csv')

# %%
df2= pd.read_csv("filtered.csv")
df3= pd.read_csv("filtered1.csv")
df2=pd.DataFrame(df2)
df3=pd.DataFrame(df3)
frames = [df2, df3]
result = pd.concat(frames)
print(result)
# Out:
#        Unnamed: 0  ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0             115    1575         124   112906      1.0     4412.0
# 1             238    1698         134   167887      1.0     3963.0
# 2             259    1719         136   184644      1.0     4375.0
# 3             378     607          75   112086      1.0     4241.0
# 4             452     681          85   116630      1.0     4241.0
# ...           ...     ...         ...      ...      ...        ...
# 11431      650341  637846       97023   148411      1.0    41401.0
# 11432      650487  630661       95561   162189      1.0    42823.0
# 11433      650664  631774       95818   102242      1.0    41401.0
# 11434      650905  638413       97152   184093      1.0    42731.0
# 11435      651000  639756       97488   161999      1.0    43411.0
#
# [16740 rows x 6 columns]

# %%
result = result.drop(columns="Unnamed: 0")
print(result)
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0        1575         124   112906      1.0     4412.0
# 1        1698         134   167887      1.0     3963.0
# 2        1719         136   184644      1.0     4375.0
# 3         607          75   112086      1.0     4241.0
# 4         681          85   116630      1.0     4241.0
# ...       ...         ...      ...      ...        ...
# 11431  637846       97023   148411      1.0    41401.0
# 11432  630661       95561   162189      1.0    42823.0
# 11433  631774       95818   102242      1.0    41401.0
# 11434  638413       97152   184093      1.0    42731.0
# 11435  639756       97488   161999      1.0    43411.0
#
# [16740 rows x 5 columns]

# %%
result.to_csv('C:/Users/Utente principale/Desktop/Tesi Ms/FilteredFinal.csv')

# %%
finale= pd.read_csv("FilteredFinal.csv", index_col='SUBJECT_ID')
finale
# Out:
#             Unnamed: 0  ROW_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# SUBJECT_ID
# 124                  0    1575   112906      1.0     4412.0
# 134                  1    1698   167887      1.0     3963.0
# 136                  2    1719   184644      1.0     4375.0
# 75                   3     607   112086      1.0     4241.0
# 85                   4     681   116630      1.0     4241.0
# ...                ...     ...      ...      ...        ...
# 97023            11431  637846   148411      1.0    41401.0
# 95561            11432  630661   162189      1.0    42823.0
# 95818            11433  631774   102242      1.0    41401.0
# 97152            11434  638413   184093      1.0    42731.0
# 97488            11435  639756   161999      1.0    43411.0
#
# [16740 rows x 5 columns]

# %%
finale = finale.drop(columns="Unnamed: 0")
finale
# Out:
#             ROW_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# SUBJECT_ID
# 124           1575   112906      1.0     4412.0
# 134           1698   167887      1.0     3963.0
# 136           1719   184644      1.0     4375.0
# 75             607   112086      1.0     4241.0
# 85             681   116630      1.0     4241.0
# ...            ...      ...      ...        ...
# 97023       637846   148411      1.0    41401.0
# 95561       630661   162189      1.0    42823.0
# 95818       631774   102242      1.0    41401.0
# 97152       638413   184093      1.0    42731.0
# 97488       639756   161999      1.0    43411.0
#
# [16740 rows x 4 columns]

# %%
dat=np.fromfile('3647298n.dat', dtype="byte")
dat
# Out:
# array([  30,   98,    0, ..., -128,    1, -128], dtype=int8)

# %%
dat=np.fromfile('3647298_0002.dat', dtype="byte")
dat
# Out:
# array([ 123,  -86, -117, ...,    0,    0,    0], dtype=int8)

# %%
import wfdb

# %%
import matplotlib.pyplot as plt

# %%
record = wfdb.rdrecord('3647298_0002') 
wfdb.plot_wfdb(record=record, title='Record from PhysioNet') 
display(record.__dict__)
# Out:
# {'record_name': '3647298_0002',
#  'n_sig': 2,
#  'fs': 125,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 7151064,
#  'base_time': datetime.time(21, 16, 6, 488000),
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['III', 'V'],
#  'p_signal': array([[0.46875   , 0.83464567],
#         [0.59375   , 0.87401575],
#         [0.625     , 0.88188976],
#         ...,
#         [       nan,        nan],
#         [       nan,        nan],
#         [       nan,        nan]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['3647298_0002.dat', '3647298_0002.dat'],
#  'fmt': ['80', '80'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [None, None],
#  'adc_gain': [128.0, 127.0],
#  'baseline': [-65, -64],
#  'units': ['mV', 'mV'],
#  'adc_res': [8, 8],
#  'adc_zero': [0, 0],
#  'init_value': [-5, 42],
#  'checksum': [16427, 14126],
#  'block_size': [0, 0]}

# %%
record = wfdb.rdrecord('3002540_0001') 
wfdb.plot_wfdb(record=record, title='Record from PhysioNet') 
display(record.__dict__)
# Out:
# {'record_name': '3002540_0001',
#  'n_sig': 5,
#  'fs': 125,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 517250,
#  'base_time': datetime.time(10, 43, 11, 672000),
#  'base_date': None,
#  'comments': [],
#  'sig_name': ['RESP', 'II', 'V', 'AVR', 'PLETH'],
#  'p_signal': array([[-4.88639140e-04,  1.09863281e-01,  1.18505859e+00,
#           6.65039062e-01,  2.00195503e+00],
#         [-4.88639140e-04,  1.15234375e-01,  1.18505859e+00,
#           6.60156250e-01,  2.00195503e+00],
#         [-4.88639140e-04,  1.04980469e-01,  1.17968750e+00,
#           6.65039062e-01,  2.00195503e+00],
#         ...,
#         [-4.88639140e-04, -3.46679688e-02,  1.22998047e+00,
#           8.30078125e-01,  2.00195503e+00],
#         [-4.88639140e-04, -4.00390625e-02,  1.24462891e+00,
#           8.30078125e-01,  2.00195503e+00],
#         [-4.88639140e-04, -2.49023438e-02,  1.23974609e+00,
#           8.24707031e-01,  2.00195503e+00]]),
#  'd_signal': None,
#  'e_p_signal': None,
# ...
